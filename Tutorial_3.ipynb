# %% [markdown]
# <a href="https://colab.research.google.com/github/LIMJIALIH/WIA1007/blob/main/Tutorial_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

df = pd.read_csv('/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv')
#df.head()
#df.info()
#df.head(2)
#x = df[['How old are you?']]
#x.head()

#salary = df[['What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)']]
#salary.head()
#df['What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)'] = df['What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)'].replace(',','',regex=True)
#df['What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)'] = df['What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)'].astype(int)
#df.info()

#x = df[df['What is your annual salary? (You\'ll indicate the currency in a later question. If you are part-time or hourly, please enter an annualized equivalent -- what you would earn if you worked the job 40 hours a week, 52 weeks a year.)'] < 50000]
#x.head()

#x = df['Context']
#x.info()
#y = x[x.isna()]
#y
# Out:
#              Timestamp How old are you?  What industry do you work in?  \
# 2   4/27/2021 11:02:38            25-34  Accounting, Banking & Finance
# 6   4/27/2021 11:02:51            25-34                     Publishing
# 9   4/27/2021 11:03:02            35-44  Accounting, Banking & Finance
# 10  4/27/2021 11:03:03            25-34                     Nonprofits
# 14  4/27/2021 11:03:11            18-24                    Health care
#
#                    Job title  \
# 2       Marketing Specialist
# 6       Publishing Assistant
# 9          Senior Accountant
# 10            Office Manager
# 14  Patient care coordinator
#
#    If your job title needs additional context, please clarify here:  \
# 2                                                 NaN
# 6                                                 NaN
# 9                                                 NaN
# 10                                                NaN
# 14                                                NaN
#
# ...
