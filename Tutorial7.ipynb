# %% [markdown]
# <a href="https://colab.research.google.com/github/LIMJIALIH/WIA1007/blob/main/Tutorial7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

df_salary = pd.read_csv('/Ask A Manager Salary Survey 2021 (Responses) - Form Responses 1.csv')
df_extra = pd.read_csv('/xtra_info.csv')
df_master = pd.concat([df_salary,df_extra],axis=1)
df_master.boxplot(figsize=(10,5))
# Out:
# <Axes: >

# %%
#Correlation analysis
#Three type of method, Pearson, Spearman and also kendall
#Pearson measure the linear  correlation between two variables
#Spearman measure the monotonic correlation between two variable
#kendall
df_numerical.corr()
